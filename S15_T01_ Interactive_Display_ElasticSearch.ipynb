# %% [markdown]
# <div class="alert alert-block alert-info"><font size="6"><b>Sprint 15 Task 1 (S15_T01)</b></font><h6 align="right"><u>Author: Alberto Achaval</u></h6></div>

# %% [markdown]
# ## <SPAN style=color:#1F618D>Level 1</SPAN>

# %% [markdown]
# ### <SPAN style=color:#1F618D>Practice 1</SPAN>

# %% [markdown]
# <SPAN style=color:#1F618D>Download Kibana and show some graphs using sample datasets.</SPAN>

# %% [markdown]
#  Elastic (ELK) STACK installed on windows and sample data downloaded:

# %% [markdown]
# ![Installation.png](attachment:Installation.png)

# %% [markdown]
# #### eCommerce Sample dataset: graphs
#
# Here we have a visualization about "Sales by Category" from the eCommerce sample data:

# %% [markdown]
# ![%5BeCommerce%5D%20Sales%20by%20Category.png](attachment:%5BeCommerce%5D%20Sales%20by%20Category.png)

# %% [markdown]
# Men's and Women's Clothing are the most pricey followed by Women's Shoes.

# %% [markdown]
# Average Sales per Region:

# %% [markdown]
# ![%5BeCommerce%5D%20Average%20Sales%20Per%20Region.png](attachment:%5BeCommerce%5D%20Average%20Sales%20Per%20Region.png)

# %% [markdown]
# ![transactions_by_city.png](attachment:transactions_by_city.png)

# %% [markdown]
# Most transactions are made from New York.

# %% [markdown]
# ![balance_table.png](attachment:balance_table.png)

# %% [markdown]
# Transactions per day:

# %% [markdown]
# ![Transactions_Day.png](attachment:Transactions_Day.png)

# %% [markdown]
# Most sold products:

# %% [markdown]
# ![most_sold.png](attachment:most_sold.png)

# %% [markdown]
# Seems that black colour it's the most demanded.

# %% [markdown]
# Sales by gender:

# %% [markdown]
# ![sales_by_gender.png](attachment:sales_by_gender.png)

# %% [markdown]
# Total revenue:

# %% [markdown]
# ![Avg%20Sales.png](attachment:Avg%20Sales.png)

# %% [markdown]
# ## <SPAN style=color:#1F618D>Level 2</SPAN>

# %% [markdown]
# ### <SPAN style=color:#1F618D>Practice 1</SPAN>

# %% [markdown]
# <SPAN style=color:#1F618D>Implement a dashboard that interactively visualizes the data you choose.</SPAN>

# %% [markdown]
# We implement a dashboard wih the visualizations we did in practice 1:

# %% [markdown]
# ![dashboard.png](attachment:dashboard.png)

# %% [markdown]
# ## <SPAN style=color:#1F618D>Level 3</SPAN>

# %% [markdown]
# ### <SPAN style=color:#1F618D>Practice 1</SPAN>

# %% [markdown]
# <SPAN style=color:#1F618D>Implement a dashboard that generates graphs using each of the different types of graphs offered by Kibana.</SPAN>

# %% [markdown]
# We add some more graphs from Kibana and filters:

# %% [markdown]
# ![Dashboard%202.png](attachment:Dashboard%202.png)
